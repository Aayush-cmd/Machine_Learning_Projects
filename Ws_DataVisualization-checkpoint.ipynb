# %% [markdown]
# ###DATA VISUALIZATION

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
x=np.array([12,23,34,45,51,63,68,74,79,83])
y=np.array([18,21,26,32,36,40,45,51,59,65])
z=np.array([81,76,71,65,63,57,53,44,36,29])

# %% [markdown]
# LINEPLOT

# %%
plt.plot(x,y);

# %%
plt.plot(x,z);

# %%
plt.plot(y,x);

# %%
plt.title('Line plot',fontsize = 20)
plt.xlabel('First value')
plt.ylabel('Second value')
plt.plot(x,y,marker = 'o', mfc = 'red',ls = '--',ms =7,color = 'black');
plt.grid()

# %%
plt.title('Line plot',fontsize = 20)
plt.xlabel('First value')
plt.ylabel('Second value')
plt.plot(x,z,marker = 'o', mfc = 'green',ls = '--',ms =7,color = 'black');
plt.grid()

# %%
plt.title('Line plot',fontsize = 20)
plt.xlabel('First value')
plt.ylabel('Second value')
plt.plot(x,y,marker = 'o', mfc = 'red',ls = '--',ms =7,color = 'black',label = '2023');
plt.plot(x,z,marker = 'o', mfc = 'green',ls = '--',ms =7,color = 'black',label = '2022');
plt.grid()
plt.legend();

# %%
plt.figure(figsize= (16,9))
plt.subplot(2,2,1)
plt.title('Line plot1')
plt.xlabel('First value')
plt.ylabel('Second value')
plt.plot(x,y,marker = 'o', mfc = 'red',ls = '--',ms =7,color = 'black');
plt.grid()


plt.subplot(2,2,2)
plt.title('Line plot2')
plt.xlabel('First value')
plt.ylabel('Second value')
plt.plot(x,z,marker = 'o', mfc = 'green',ls = '--',ms =7,color = 'black');
plt.grid()

# %%
df= pd.read_csv('student.csv')
df.head(3)
# Out:
#    roll    name class  marks  age
# 0     1    anil    TE  56.77   22
# 1     2    amit    TE  59.77   21
# 2     3  aniket    BE  76.88   19

# %%
plt.title('Line plot1')
plt.xlabel('roll_no.')
plt.ylabel('marks')
plt.xticks(range(0,11,1))
plt.plot(df['roll'],df['marks'],marker = 'o', mfc = 'red',ls = '--',ms =7,color = 'black');
plt.grid()

# %% [markdown]
# BARPLOT

# %%
students = [56,60,63,47,51]
cources =['java','python','c++','kotlin','c']

# %%
plt.bar(cources,students)
# Out:
# <BarContainer object of 5 artists>

# %%
students = [56,60,63,47,51]
cources =['java','python','c++','kotlin','c']
bar =plt.bar(cources,students,color = ['red','blue','green','purple','black'], edgecolor = 'black',width = 0.6,linewidth = 3,alpha =0.7);
plt.xlabel('cources')
plt.ylabel('students')
plt.yticks(range(0,90,5))
plt.bar_label(bar);

# %% [markdown]
# scatter plt

# %%
plt.scatter(x,y,color = 'red',marker='*')
plt.grid()

# %% [markdown]
# pie chart

# %%
plt.style.use('classic')
plt.title('Pie chart')
plt.pie(students,labels = cources,autopct='%.2f%%',labeldistance=1.1,
startangle=90,shadow =True,explode = [0.2,0,0,0,0.6]);

# %%
df2 = pd.read_csv('student.csv')
df2
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
df1 = pd.read_csv('Social_Network_Ads.csv')
df1
# Out:
#       User ID  Gender   Age  EstimatedSalary  Purchased
# 0    15624510    Male  19.0          19000.0          0
# 1    15810944    Male  35.0          20000.0          0
# 2    15668575  Female  26.0          43000.0          0
# 3    15603246  Female  27.0          57000.0          0
# 4    15804002    Male  19.0          76000.0          0
# ..        ...     ...   ...              ...        ...
# 395  15691863  Female  46.0          41000.0          1
# 396  15706071    Male  51.0          23000.0          1
# 397  15654296  Female  50.0          20000.0          1
# 398  15755018    Male  36.0          33000.0          0
# 399  15594041  Female  49.0          36000.0          1
#
# [400 rows x 5 columns]

# %%
plt.style.use('dark_background')
plt.figure(figsize= (16,9))
plt.subplot(2,2,1)
plt.title('Line plot')
plt.xlabel('Roll_num')
plt.ylabel('marks')
plt.plot(df2['roll'],df2['marks'],marker = 'o', mfc = 'red',ls = '--',ms =7,color = 'white')
plt.grid()


students = [56,60,63,47,51]
plt.subplot(2,2,2)
plt.title('Bar plot')
cources =['java','python','c++','kotlin','c']
bar =plt.bar(df2['name'],df2['marks'],color = ['red','blue','green','purple','black'], edgecolor = 'black',width = 0.6,linewidth = 3,alpha =0.7);
plt.xlabel('roll_num')
plt.ylabel('marks')
plt.yticks(range(0,90,5))
plt.bar_label(bar)


plt.subplot(2,2,3)
plt.scatter(df2['roll'],df2['marks'],color = 'red',marker='*')
plt.title('Scatter chart')
plt.grid()



plt.subplot(2,2,4)
plt.title('Pie chart')
plt.pie(df1['Purchased'].value_counts(),labels = ['Purchased','Not Purchased'],autopct='%.2f%%',labeldistance=1.1,
startangle=90,shadow =True,explode = [0,0.3],
radius =1.1);

# %% [markdown]
# histogram

# %%
df
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
plt.title('Ages Of customer')
plt.xlabel('Age')
plt.ylabel('Number of Employees')
plt.yticks(range(0,150,10))
plt.hist(df1['Age'],bins = range(0,61,10),color = 'red');
plt.grid();

# %%
df1      #Social_Network_Ads.csv
# Out:
#       User ID  Gender   Age  EstimatedSalary  Purchased
# 0    15624510    Male  19.0          19000.0          0
# 1    15810944    Male  35.0          20000.0          0
# 2    15668575  Female  26.0          43000.0          0
# 3    15603246  Female  27.0          57000.0          0
# 4    15804002    Male  19.0          76000.0          0
# ..        ...     ...   ...              ...        ...
# 395  15691863  Female  46.0          41000.0          1
# 396  15706071    Male  51.0          23000.0          1
# 397  15654296  Female  50.0          20000.0          1
# 398  15755018    Male  36.0          33000.0          0
# 399  15594041  Female  49.0          36000.0          1
#
# [400 rows x 5 columns]

# %%
plt.style.use('default')
plt.title('Salary of employees')
plt.xlabel('Estimated salary')
plt.ylabel('Number of Employees')
plt.yticks(range(0,200,10))
plt.hist(df1['EstimatedSalary'],bins = range(20000,100000,10000),color = 'red', edgecolor = 'white')
plt.grid();

# %% [markdown]
# BOXPLOT

# %%
plt.boxplot(df1['Age']);

# %%
df1
# Out:
#       User ID  Gender   Age  EstimatedSalary  Purchased
# 0    15624510    Male  19.0          19000.0          0
# 1    15810944    Male  35.0          20000.0          0
# 2    15668575  Female  26.0          43000.0          0
# 3    15603246  Female  27.0          57000.0          0
# 4    15804002    Male  19.0          76000.0          0
# ..        ...     ...   ...              ...        ...
# 395  15691863  Female  46.0          41000.0          1
# 396  15706071    Male  51.0          23000.0          1
# 397  15654296  Female  50.0          20000.0          1
# 398  15755018    Male  36.0          33000.0          0
# 399  15594041  Female  49.0          36000.0          1
#
# [400 rows x 5 columns]

# %%
df1['Age'].describe()
# Out:
# count    400.000000
# mean      37.655000
# std       10.482877
# min       18.000000
# 25%       29.750000
# 50%       37.000000
# 75%       46.000000
# max       60.000000
# Name: Age, dtype: float64

# %%
df1.loc[156,'Age']=75

# %%
df1.loc[40,'Age']=2

# %%
df1['Age'].describe()
# Out:
# count    400.000000
# mean      37.665000
# std       10.775577
# min        2.000000
# 25%       29.750000
# 50%       37.000000
# 75%       46.000000
# max       75.000000
# Name: Age, dtype: float64

# %%
df1
# Out:
#       User ID  Gender   Age  EstimatedSalary  Purchased
# 0    15624510    Male  19.0          19000.0          0
# 1    15810944    Male  35.0          20000.0          0
# 2    15668575  Female  26.0          43000.0          0
# 3    15603246  Female  27.0          57000.0          0
# 4    15804002    Male  19.0          76000.0          0
# ..        ...     ...   ...              ...        ...
# 395  15691863  Female  46.0          41000.0          1
# 396  15706071    Male  51.0          23000.0          1
# 397  15654296  Female  50.0          20000.0          1
# 398  15755018    Male  36.0          33000.0          0
# 399  15594041  Female  49.0          36000.0          1
#
# [400 rows x 5 columns]

# %%
q3 = np.percentile(df1['Age'],75)
q1 = np.percentile(df1['Age'],25)

# %%
q3,q1
# Out:
# (46.0, 29.75)

# %%
iqr =q3 -q1

# %%
iqr
# Out:
# 16.25

# %%
ub = q3 + (1.5*iqr)
lb = q1 - (1.5*iqr)

# %%
ub,lb
# Out:
# (70.375, 5.375)

# %%
df1 = df1[(df1['Age'] > lb) & (df1['Age']<ub)]

# %%
df1
# Out:
#       User ID  Gender   Age  EstimatedSalary  Purchased
# 0    15624510    Male  19.0          19000.0          0
# 1    15810944    Male  35.0          20000.0          0
# 2    15668575  Female  26.0          43000.0          0
# 3    15603246  Female  27.0          57000.0          0
# 4    15804002    Male  19.0          76000.0          0
# ..        ...     ...   ...              ...        ...
# 395  15691863  Female  46.0          41000.0          1
# 396  15706071    Male  51.0          23000.0          1
# 397  15654296  Female  50.0          20000.0          1
# 398  15755018    Male  36.0          33000.0          0
# 399  15594041  Female  49.0          36000.0          1
#
# [398 rows x 5 columns]

# %% [markdown]
# SEABORN

# %%
import seaborn as sns
df2 = sns.load_dataset('tips')

# %%
df2
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.jointplot(x= 'tip',y = 'total_bill',data = df2,hue = 'sex');

# %%
sns.histplot(df2['tip'],kde=2);

# %%
sns.boxplot(x= 'day',y = 'tip',data = df2);

# %%
df3 = sns.load_dataset('iris')
df3
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.pairplot(df3,hue = 'species');
