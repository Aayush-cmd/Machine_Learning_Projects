# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('grapes_new.csv')

# %%
df.head()
# Out:
#    COLOR_INTENSITY       SHAPE  RIPENESS_PER  ALCOHOL_PER  MALIC_ACID_PER  \
# 0           120.53  elliptical         16.73        14.23            1.71
# 1           112.57  elliptical         20.30        13.20            1.78
# 2           120.78  elliptical         20.81        13.16            2.36
# 3           134.17  elliptical         19.47        14.37            1.95
# 4           112.19       round         17.57        13.24            2.59
#
#     ASH  ALCALINITY_OF_ASH  MAGNESIUM_MEASURE  TOTAL_PHENOLS  FLAVANOIDS  ...  \
# 0  2.43               15.6                127           2.80        3.06  ...
# 1  2.14               11.2                100           2.65        2.76  ...
# 2  2.67               18.6                101           2.80        3.24  ...
# 3  2.50               16.8                113           3.85        3.49  ...
# 4  2.87               21.0                118           2.80        2.69  ...
#
# ...

# %%
x = df.drop(['COLOR_INTENSITY','SHAPE'], axis=1)
y = df[['COLOR_INTENSITY','SHAPE']]

# %%
df.columns
# Out:
# Index(['COLOR_INTENSITY', 'SHAPE', 'RIPENESS_PER', 'ALCOHOL_PER',
#        'MALIC_ACID_PER', 'ASH', 'ALCALINITY_OF_ASH', 'MAGNESIUM_MEASURE',
#        'TOTAL_PHENOLS', 'FLAVANOIDS', 'PROANTHOCYANINS', 'HUE', 'PROLINE',
#        'TEMPERATURE', 'AVG_HUMIDITY', 'FERT_NITRO_PER', 'WATER_O2_PER',
#        'WATER_PH', 'FER_P2O5_PER', 'SOIL_TYPE', 'CLASS'],
#       dtype='object')

# %%
df.isnull()
# Out:
#      COLOR_INTENSITY  SHAPE  RIPENESS_PER  ALCOHOL_PER  MALIC_ACID_PER    ASH  \
# 0              False  False         False        False           False  False
# 1              False  False         False        False           False  False
# 2              False  False         False        False           False  False
# 3              False  False         False        False           False  False
# 4              False  False         False        False           False  False
# ..               ...    ...           ...          ...             ...    ...
# 189            False  False         False        False           False  False
# 190            False  False         False        False           False  False
# 191            False  False         False        False           False  False
# 192            False  False         False        False           False  False
# 193            False  False         False        False           False  False
#
# ...

# %%
df.isnull().sum()
# Out:
# COLOR_INTENSITY      0
# SHAPE                0
# RIPENESS_PER         2
# ALCOHOL_PER          3
# MALIC_ACID_PER       0
# ASH                  0
# ALCALINITY_OF_ASH    6
# MAGNESIUM_MEASURE    0
# TOTAL_PHENOLS        0
# FLAVANOIDS           0
# PROANTHOCYANINS      0
# HUE                  2
# PROLINE              0
# TEMPERATURE          0
# AVG_HUMIDITY         0
# FERT_NITRO_PER       0
# WATER_O2_PER         4
# WATER_PH             0
# FER_P2O5_PER         0
# SOIL_TYPE            0
# CLASS                0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 17

# %%
df.isnull().sum().sum()
# Out:
# 17

# %%
df.bfill(inplace = True)

# %%
df.isnull().sum().sum()
# Out:
# 1

# %%
df.ffill(inplace = True)

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
plt.style.use('dark_background')
plt.figure(figsize= (16,9))
sns.countplot(x='COLOR_INTENSITY',data =df)
plt.show()

# %%
col=df['COLOR_INTENSITY'].head(10)
plt.title('Pie chart')
plt.pie(col.value_counts());
col=df['COLOR_INTENSITY'].head(10)
plt.title('Pie chart')
plt.pie(col.value_counts(),labels=col.value_counts().index,autopct='%2f%%',labeldistance=1.1);

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='SHAPE', data=df)
plt.title('Distribution of Grape Shapes')
plt.xlabel('SHAPE')
plt.ylabel('COUNT')
plt.xticks(rotation=45)
plt.show()


soil_type_counts = df['SOIL_TYPE'].value_counts()
plt.figure(figsize=(8, 6))
plt.pie(soil_type_counts, labels=soil_type_counts.index, autopct='%1.1f%%', startangle=90)
plt.title('Distribution of Soil Types')
plt.show()

# %%
df.head()
# Out:
#    COLOR_INTENSITY       SHAPE  RIPENESS_PER  ALCOHOL_PER  MALIC_ACID_PER  \
# 0           120.53  elliptical         16.73        14.23            1.71
# 1           112.57  elliptical         20.30        13.20            1.78
# 2           120.78  elliptical         20.81        13.16            2.36
# 3           134.17  elliptical         19.47        14.37            1.95
# 4           112.19       round         17.57        13.24            2.59
#
#     ASH  ALCALINITY_OF_ASH  MAGNESIUM_MEASURE  TOTAL_PHENOLS  FLAVANOIDS  ...  \
# 0  2.43               15.6                127           2.80        3.06  ...
# 1  2.14               11.2                100           2.65        2.76  ...
# 2  2.67               18.6                101           2.80        3.24  ...
# 3  2.50               16.8                113           3.85        3.49  ...
# 4  2.87               21.0                118           2.80        2.69  ...
#
# ...

# %%
sns.kdeplot(df['ALCOHOL_PER'], fill=True)
plt.title('Distribution of Alcohol Percentage')
plt.xlabel('Alcohol Percentage')
plt.show()

sns.kdeplot(df['TEMPERATURE'], fill=True)
plt.title('Distribution of Temperature')
plt.xlabel('Temperature')
plt.show()

sns.kdeplot(df['AVG_HUMIDITY'], fill=True)
plt.title('Distribution of Average Humidity')
plt.xlabel('Average Humidity')
plt.show()

sns.kdeplot(df['FERT_NITRO_PER'], fill=True)
plt.title('Distribution of Fertilizer Nitrogen Percentage')
plt.xlabel('Fertilizer Nitrogen Percentage')
plt.show()

sns.kdeplot(df['WATER_PH'], fill=True)
plt.title('Distribution of Water pH')
plt.xlabel('Water pH')
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder

categorical_cols = ['SHAPE', 'SOIL_TYPE']

label_encoders = {}
for col in categorical_cols:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])
    label_encoders[col] = le

# %%
from sklearn.feature_selection import SelectKBest, chi2


x = df.drop('CLASS', axis=1)  
y = df['CLASS']


selector = SelectKBest(chi2, k=5) 
x_new = selector.fit_transform(x, y)


selected_feature_indices = selector.get_support(indices=True)


selected_feature_names = x.columns[selected_feature_indices]

print("Top 5 features selected by chi2:")
print(selected_feature_names)
# Out:
# Top 5 features selected by chi2:
# Index(['COLOR_INTENSITY', 'PROLINE', 'TEMPERATURE', 'WATER_O2_PER',
#        'FER_P2O5_PER'],
#       dtype='object')

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
x_scaled = scaler.fit_transform(x_new)

# %%
pd.DataFrame(x_scaled).describe()
# Out:
#                 0           1           2           3           4
# count  194.000000  194.000000  194.000000  194.000000  194.000000
# mean     0.322731    0.339633    0.476877    0.515958    0.543067
# std      0.193692    0.225459    0.268760    0.282306    0.254421
# min      0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.168514    0.161198    0.282906    0.283488    0.336249
# 50%      0.296081    0.283167    0.457155    0.524987    0.607291
# 75%      0.419730    0.506954    0.681758    0.748970    0.747309
# max      1.000000    1.000000    1.000000    1.000000    1.000000

# %%
from sklearn.model_selection import train_test_split

# Split the data into training and testing sets with stratification
x_train, x_test, y_train, y_test = train_test_split(
    x_scaled, y, test_size=0.2, stratify=y, random_state=42
)

print("Training set shape:", x_train.shape, y_train.shape)
print("Testing set shape:", x_test.shape, y_test.shape)
# Out:
# Training set shape: (155, 5) (155,)
# Testing set shape: (39, 5) (39,)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score

classifiers = {
    "Logistic Regression": LogisticRegression(),
    "Decision Tree": DecisionTreeClassifier(),
    "Random Forest": RandomForestClassifier(),
    "Gradient Boosting": GradientBoostingClassifier(),
    "Support Vector Machine": SVC(),
    "K-Nearest Neighbors": KNeighborsClassifier(),
    "Naive Bayes": GaussianNB()
}


results = {}
for name, clf in classifiers.items():
    clf.fit(x_train, y_train)
    y_pred = clf.predict(x_test)
    accuracy = accuracy_score(y_test, y_pred)
    results[name] = accuracy


for name, accuracy in results.items():
    print(f"{name}: {accuracy:.2f}")
# Out:
# Logistic Regression: 1.00
# Decision Tree: 0.90
# Random Forest: 1.00
# Gradient Boosting: 0.95
# Support Vector Machine: 1.00
# K-Nearest Neighbors: 1.00
# Naive Bayes: 1.00
